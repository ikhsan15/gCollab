# %%
import os, sys

# %% [markdown]
# open a file

# %%
fd = os.open("sample_data/data_rahasia.csv",os.O_RDWR | os.O_CREAT)

# %% [markdown]
# Write one string

# %%
baris = "Ini hanya test doang..."

# %% [markdown]
# rubah format string / encode

# %%
b = baris.encode()

# %% [markdown]
# tulis ke file melalui file descriptor

# %%
os.write(fd,b)
# Out:
# 23

# %% [markdown]
# singkronisasi proses penulisan

# %%
os.fsync(fd)

# %% [markdown]
# pindah offset ke posisi pertama

# %%
os.lseek(fd,0,0)
# Out:
# 0

# %%
baris_baru = "XXX"
data = baris_baru.encode()

# %%
os.write(fd,data)
# Out:
# 3

# %%
os.close(fd)

# %% [markdown]
# 1.

# %%
import os, sys

# %% [markdown]
# Menulis dan menginputkan nama file

# %%
fd = input("Nama file : ")
# Out:
# Nama file : sample_data/coba.txt

# %%
file = os.open(fd, os.O_CREAT | os.O_RDWR  )

# %% [markdown]
# Menulis isi file

# %%
isi = "ini isi text file tes.txt"

# %% [markdown]
# rubah format string / encode

# %%
b = isi.encode()

# %% [markdown]
# tulis ke file melalui file descriptor

# %%
os.write(fFile,b)

# %%
os.close(fd)

# %% [markdown]
# 2.

# %%
filaA = input("Masukan nama file pertama: ")
# Out:
# Masukan nama file pertama: sample_data/tujuan.txt

# %%
filaB = input("Masukan nama file yg mau dicopy isinya: ")
# Out:
# Masukan nama file yg mau dicopy isinya: /content/sample_data/anscombe.json

# %%
filea = os.open(fileA, os.O_CREAT | os.O_RDWR  )

# %%
fileb = os.open(fileB, os.O_CREAT | os.O_RDWR  )
